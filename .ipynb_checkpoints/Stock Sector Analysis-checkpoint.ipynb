# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# %%
NDQone = 'https://data.nasdaq.com/api/v3/datasets/wiki/'
Ticker1 = ['CVX', 'MRO', 'XOM', 'FCEL', 'PLUG', 'VLO']
Ticker2 = ['AMD', 'AMZN', 'AAPL', 'INTC', 'NVDA', 'MSFT']
Ticker3 = ['CVS', 'VRTX', 'BIIB', 'MOH', 'MRK', 'HUM']
Ticker4 = ['TGT', 'WMT', 'PG', 'KO', 'COST', 'HD']

TickerListList = [Ticker1, Ticker2, Ticker3, Ticker4]
TickerList = 'Ticker1', 'Ticker2', "Ticker3", 'Ticker4'

NDQthree = '.json?collapse=monthly&start_date=2005-01-01&end_date=2010-12-01&api_key='
APIKEY = '4xTnNzSoDevupJMaZ7wa'

#Creates our 4 sector Dataframes
EnergyDF = pd.DataFrame()
TechDF = pd.DataFrame()
HealthDF = pd.DataFrame()
ConsumerDF = pd.DataFrame()



#For each Sector...
for i in range(0, 4):
    #make lists that wipe in the next for loop
    dates = []
    opens = []
    closes = []
    stock = []
    
    #For each stock..
    for a in range(0, 6):   # 6 tickers per sector
        #Request the data
        response = requests.get(NDQone + TickerListList[i][a] + NDQthree + APIKEY)
        NDQ_json = response.json()
        
        #Try inserting the data to the lists we need for the 4 Dataframes
        try:
            for x in range(0, 72):    #6 years of data
                dates.insert(0, NDQ_json['dataset']['data'][x][0])
                opens.insert(0, NDQ_json['dataset']['data'][x][8])  #1
                closes.insert(0, NDQ_json['dataset']['data'][x][11])  #4
                stock.insert(0, TickerListList[i][a])                 
                
        except: 
            print("API Data not found " + str(TickerListList[i][a]))
            pass
      #  for x in range(0, 72):
      #      opens[x] = '${:.2f}'.format(opens[x])
    #Add to the DataFrames depending on the outer 'Sector' For Loop
    if(i == 0):
        EnergyDF["Ticker"] = stock
        EnergyDF["Open Costs"] = opens
        EnergyDF["Closing Costs"] = closes
        EnergyDF["Date"] = dates
    if(i == 1):
        TechDF["Ticker"] = stock
        TechDF["Open Costs"] = opens
        TechDF["Closing Costs"] = closes
        TechDF["Date"] = dates
    if(i == 2):
        HealthDF["Ticker"] = stock
        HealthDF["Open Costs"] = opens
        HealthDF["Closing Costs"] = closes
        HealthDF["Date"] = dates
    if(i == 3):
        ConsumerDF["Ticker"] = stock
        ConsumerDF["Open Costs"] = opens
        ConsumerDF["Closing Costs"] = closes
        ConsumerDF["Date"] = dates

# %%
NDQ_json['dataset']['data'][4]
# Out:
# ['2010-08-31',
#  27.63,
#  28.08,
#  27.55,
#  27.82,
#  12408200.0,
#  0.23625,
#  1.0,
#  23.559022337863,
#  23.942719770075,
#  23.490809461025,
#  23.721027920352,
#  12408200.0]

# %%
#a = Dataframe to split, b = individual ticker list, c = new DF
def DFReorg(a, b,c ):
    #Splits the DF into 6, per ticker
    Ticker1_df = a[a['Ticker'] == b[0]].reset_index()
    #Adds the tickers to the new DF
    c['Ticker1_Opening'] = Ticker1_df['Open Costs']
    #clears the tickerDF
    Ticker1_df = []
    Ticker2_df = a[a['Ticker'] == b[1]].reset_index()
    c['Ticker2_Opening'] = Ticker2_df['Open Costs']
    Ticker2_df = []
    Ticker3_df = a[a['Ticker'] == b[2]].reset_index()
    c['Ticker3_Opening'] = Ticker3_df['Open Costs']
    Ticker3_df = []
    Ticker4_df = a[a['Ticker'] == b[3]].reset_index()
    c['Ticker4_Opening'] = Ticker4_df['Open Costs']
    Ticker4_df = []
    Ticker5_df = a[a['Ticker'] == b[4]].reset_index()
    c['Ticker5_Opening'] = Ticker5_df['Open Costs']
    Ticker5_df = []
    Ticker6_df = a[a['Ticker'] == b[5]].reset_index()
    c['Ticker6_Opening'] = Ticker6_df['Open Costs']
    Ticker6_df = []
    
EnergynewDF = pd.DataFrame()
TechnewDF = pd.DataFrame()
HealthnewDF = pd.DataFrame()
ConsumernewDF = pd.DataFrame()

#used for referencing DFs in the def
DfList = ['EnergyDF', 'TechDF', 'HealthDF', 'ConsumerDF']
DFnewList = ['EnergynewDF', 'TechnewDF', 'HealthnewDF', 'ConsumernewDF']

#a.rename(columns = {'Ticker1_Opening': b[0], 'Ticker2_Opening' : b[1], 'Ticker3_Opening': b[2], 'Ticker4_Opening' : b[3],  'Ticker5_Opening': b[4], 'Ticker6_Opening' : b[5]}, inplace=True)

# %%
DFReorg(EnergyDF, Ticker1, EnergynewDF)
DFReorg(TechDF, Ticker2, TechnewDF)
DFReorg(HealthDF, Ticker3, HealthnewDF)
DFReorg(ConsumerDF, Ticker4, ConsumernewDF)

# %%
#Creates aggregate dataframes for sector comparison (Will do comparison in later part of the code)

#a = input df
def agg(a):        #Sums up all columns
    c = a["Ticker1_Opening"]+a["Ticker2_Opening"]+a["Ticker3_Opening"]+a["Ticker4_Opening"]+a["Ticker5_Opening"]+a["Ticker6_Opening"]
    return c

energyagg_s = agg(EnergynewDF)
techagg_s = agg(TechnewDF)
healthagg_s = agg(HealthnewDF)
consumeragg_s = agg(ConsumernewDF)

#creating datafrmaes for next step
energyagg_df = pd.DataFrame()
techagg_df = pd.DataFrame()
healthagg_df = pd.DataFrame()
consumeragg_df = pd.DataFrame()

# %%
energyagg_df['Agg'] = pd.DataFrame(energyagg_s)
techagg_df['Agg'] = pd.DataFrame(techagg_s)
healthagg_df['Agg'] = pd.DataFrame(healthagg_s)
consumeragg_df['Agg'] = pd.DataFrame(consumeragg_s)

# %%
EnergynewDF.rename(columns = {'Ticker1_Opening': Ticker1[0], 'Ticker2_Opening' : Ticker1[1], 'Ticker3_Opening': Ticker1[2], 'Ticker4_Opening' : Ticker1[3],  'Ticker5_Opening': Ticker1[4], 'Ticker6_Opening' : Ticker1[5]}, inplace=True)
TechnewDF.rename(columns = {'Ticker1_Opening': Ticker2[0], 'Ticker2_Opening' : Ticker2[1], 'Ticker3_Opening': Ticker2[2], 'Ticker4_Opening' : Ticker2[3],  'Ticker5_Opening': Ticker2[4], 'Ticker6_Opening' : Ticker2[5]}, inplace=True)
HealthnewDF.rename(columns = {'Ticker1_Opening': Ticker3[0], 'Ticker2_Opening' : Ticker3[1], 'Ticker3_Opening': Ticker3[2], 'Ticker4_Opening' : Ticker3[3],  'Ticker5_Opening': Ticker3[4], 'Ticker6_Opening' : Ticker3[5]}, inplace=True)
ConsumernewDF.rename(columns = {'Ticker1_Opening': Ticker4[0], 'Ticker2_Opening' : Ticker4[1], 'Ticker3_Opening': Ticker4[2], 'Ticker4_Opening' : Ticker4[3],  'Ticker5_Opening': Ticker4[4], 'Ticker6_Opening' : Ticker4[5]}, inplace=True)

# %%
#Old Code for single Stocks. Keeping for reuse later for Sector Comparisons.
def splot(a):
    plot1 = a.plot(figsize=(18, 10), lw = 3, fontsize = 18, xticks = [0, 12, 24, 36, 48, 60, 72])
    plot1.set_xlabel("Time in months", fontsize=20)
    plot1.set_ylabel("Stock Price in USD", fontsize=20)
    plot1.set_title('Stock Performance over Time', fontsize=20)
    plot1.set_facecolor('#e7e7e7')
    plot1.legend(fontsize=16)

# %%
sectors = ['Energy', 'Technology', 'Healthcare', 'ConsumerStaples']

x = 0
for i in sectors:
    x = x + 1
    if(x == 1):
        splot(EnergynewDF)
    if(x == 2):
        splot(TechnewDF)
    if(x == 3):
        splot(HealthnewDF)
    if(x == 4):
        splot(ConsumernewDF)
    plt.savefig('output_data/{}.png'.format(i))

# %%
#Makes all the subplots
fig, ax = plt.subplots(2,2, figsize=(15, 9), sharex=True, sharey=True)
fig.suptitle("Stock Sector Comparison", fontsize = 18)

ax[0,0].set_title("Energy Stocks", fontsize = 15) 
ax[0,1].set_title("Tech Stocks",fontsize = 15) 
ax[1,1].set_title("Health Stocks",fontsize = 15) 
ax[1,0].set_title("Cons. Staples Stocks",fontsize = 15) 

#Any index will do, its the X axis. 
fig.supxlabel("Time in months", fontsize = 18)
fig.supylabel("Stock Prices", fontsize = 18)
fig.set_facecolor('#e7e7e7')

ax[0,0].plot(EnergynewDF)
ax[0,1].plot(TechnewDF)
ax[1,1].plot(HealthnewDF)
ax[1,0].plot(ConsumernewDF)

# %%
#sum up all aggs into one DF

sector_df = pd.DataFrame()
sector_df['Energy'] = energyagg_df['Agg']
sector_df['Technology'] = techagg_df['Agg']
sector_df['Health'] = healthagg_df['Agg']
sector_df['Consumer'] = consumeragg_df['Agg']

# %%
#We also still need to do an aggregate sector to sector comparison.
#Something along the lines of Add all Open costs for a sector per row.

# %%
#a = inputdf
def comparisonplot(a):
    row = a.iloc[71] - a.iloc[0]    
    plot1 = row.plot.bar(figsize=(18, 10), lw = 3, fontsize = 18, rot=45)
    plot1.set_xlabel("Time in months", fontsize=20)
    plot1.set_ylabel("Stock Price in USD", fontsize=20)
    plot1.set_title('Stock Performance over Time', fontsize=20)
    plot1.set_facecolor('#e7e7e7')
    plot1.bar_label(plot1.containers[0], fontsize = 15, padding=4)

# %%
comparisonplot(sector_df)
